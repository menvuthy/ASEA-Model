# %% [markdown]
# ## **Automated Shoreline Extraction and Analysis Model**
#
# *Published Version 10.22*
#
#
# ---
#
# ASEA model is a robust and user-friendly model capable of extracting the shoreline from Landsat satellite imagery with high accuracy and calculating the shoreline change between the past and present condition.
#
# ---
#
#
# *Developed by Men Vuthy, 2022*
#
# *GIS/Remote Sensing Specialist, River department, Nippon Koei Co., Ltd, Tokyo, Japan*

# %% [markdown]
# **Set path to ASEAModel directory**

# %%
cd /content/drive/MyDrive/Colab Notebooks/ASEAModel/ASEAModel-kmeans
# Out:
# /content/drive/MyDrive/Colab Notebooks/ASEAModel/ASEAModel-kmeans

# %% [markdown]
# **Authenticate Google Earth Engine**

# %%
# !earthengine authenticate
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=C6DxNtBJ9WtrnF5t6NdDqZ-MHe8x2SW597UtsVwt0ac&tc=B4uTzgfIrfra_w1rvJj9aY4hkN4C3trOsaP5WUZInyE&cc=scayDw6IdBLr607nMwKkIyhpyYl0xf1AWMsjgVq8JZo
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1ARtbsJpXD24PKW2F_iAB1vxTHfCVHQG4YcDKNwPQEM2JV54KVO45dHHk_Ek
#
# Successfully saved authorization token.

# %% [markdown]
# **Install environment**

# %%
# !apt install libspatialindex-dev
# !pip install -r requirements.txt

# %% [markdown]
# **1. Pre-process and download Landsat image from Google Earth Engine**
#
# Open 'parameters.py' file:
#
# - Set area of interest by generating geometry from [Google Earth Engine](https://code.earthengine.google.com)
# - Set the date range
#
# *Check **<docs/generate-geometry.gif>** to see the tutorial on how to generate geometry.*

# %%
# !python execute_1_download_satellite_image.py
# Out:
# Downloading grid image: 1
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Downloading grid image: 1
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Downloading grid image: 1
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Downloading grid image: 1
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Downloading grid image: 1
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Downloading grid image: 1
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Download is finished!

# %% [markdown]
# **2. Extract shoreline**

# %%
# !python execute_2_shoreline_extraction.py
# Out:
# Shoreline extraction is finished!

# %% [markdown]
# **3. Calculate growth and retreat**

# %%
# !python execute_3_shoreline_analysis.py
# Out:
# Shoreline analysis is finished!

# %% [markdown]
# **4. Create maps of shorelines and shoreline changes**

# %%
# !python execute_4_mapping_shoreline.py
# Out:
# Shoreline change map is created!

# %% [markdown]
# ---
